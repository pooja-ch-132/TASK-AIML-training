# %% [markdown]
# **Functions, Modules, and Packages.**

# %%
#A function is a block of code that performs a specific task and can be reused whenever needed.
def add(a,b):
  print("Sum",a+b)
add(1,2)
# Out:
# Sum 3

# %%
def add(a,b):
  return a+b
add(2,4)
# Out:
# 6

# %%
#Modules: A module is a Python file (.py) containing functions, variables, and classes that can be reused in other programs.
# %%writefile mymodule.py
def add(a,b):

def mul(a*b):
# Out:
# Writing mymodule.py

# %%
#A package is a collection of related modules organized in directories.

# %% [markdown]
# **Problems to practice**

# %%
#Q1. Write a function to reverse a string.
def reverse_string(text):
    return text[::-1]

s = input("Enter a string: ")
print("Reversed string:", reverse_string(s))
# Out:
# Enter a string: Lakdikapul
# Reversed string: lupakidkaL

# %%
#Q2. Write a function to check whether a number is an Armstrong number.
#Function to Check Armstrong Number
def is_armstrong(num):
    digits = len(str(num))
    total = sum(int(digit) ** digits for digit in str(num))
    return total == num

n = int(input("Enter a number: "))

if is_armstrong(n):
    print(n, "is an Armstrong number")
else:
    print(n, "is not an Armstrong number")
# Out:
# Enter a number: 1642
# 1642 is not an Armstrong number

# %%
#Q3. Write a function to generate the Fibonacci series.
#Function to Generate Fibonacci Series
def fibonacci(n):
    a, b = 0, 1

    for i in range(n):
        print(a, end=" ")
        a, b = b, a + b

terms = int(input("Enter number of terms: "))
fibonacci(terms)
# Out:
# Enter number of terms: 7
# 0 1 1 2 3 5 8

# %%
#Q4. Write a function to find the sum of digits of a number.
#Find sum of digits
def sum_of_digits(num):
    total = 0

    while num > 0:
        digit = num % 10
        total += digit
        num //= 10

    return total

n = int(input("Enter a number: "))
print("Sum of digits =", sum_of_digits(n))
# Out:
# Enter a number: 57839
# Sum of digits = 32

# %%
#Q5. Create a module for area calculations (circle, rectangle, triangle).
#Module for Area Calculations
# %%writefile area.py
import math

def circle_area(radius):
    return math.pi * radius * radius

def rectangle_area(length, breadth):
    return length * breadth

def triangle_area(base, height):
    return 0.5 * base * height
# Out:
# Writing area.py

# %%
#Q6. Create a package named shapes with modules for circle and rectangle calculations.
import area

print("Area of Circle:", area.circle_area(5))
print("Area of Rectangle:", area.rectangle_area(4, 6))
print("Area of Triangle:", area.triangle_area(8, 5))
# Out:
# Area of Circle: 78.53981633974483
# Area of Rectangle: 24
# Area of Triangle: 20.0
